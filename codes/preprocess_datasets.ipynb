# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import collections

# %%
df = pd.read_csv("train_50_topic_2.csv", sep="\t", encoding="utf-8")
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  \
# 0                  0      101366
# 1             262145       24035
# 2                  3      265931
# 3             262148      243324
# 4                  5      269035
# ...              ...         ...
# 138397        262131      182769
# 138398        262133       45801
# 138399        262135       47669
# 138400        262136      281732
# 138401        262142       73655
#
#                                                  abstract author  \
# 0       KKTC'de dağılan koalisyonun ortağı lideri Denk...    NaN
# 1       TBMM Genel Kurulu'nda, Afganistan'daki Türk Si...    NaN
# 2       BU sene modacı Zac Posen ile çalışan Vakko, bu...    NaN
# 3       Serbest piyasada 24 ayar külçe altının gram sa...  (İHA)
# 4       Sabancı Ailesinin geride duran ismi Yalçın Sab...    NaN
# ...                                                   ...    ...
# 138397  Sivas'ta yoğun kar yağışı beklentisi nedeniyle...    NaN
# 138398  Bir dargın bir barışık olsa da 2010 yılından b...    NaN
# 138399  Kamboçya hükümetinin müdahalesiyle ülkedeki FE...    NaN
# 138400  Kar yağışı İstanbul'un kuzey ve doğu bölgeleri...    NaN
# 138401  Bilecik'te çeşitli suçlardan dolayı aranması b...  (İHA)
#
#                                                   content  \
# 0       KKTC'de yaşanan siyasi çalkantı sonucu dağılan...
# 1       TBMM Genel Kurulu, Meclis Başkanvekili Mustafa...
# 2       Vakko, bu sezon ünlü New York’lu moda tasarımc...
# 3       İstanbul Kapalıçarşı'da 216,20 liradan alınan ...
# 4       - Burak Mavi / 39 yıl sonunda Sabancı Holding’...
# ...                                                   ...
# 138397  Sivas Valiliği'nden yapılan yazılı açıklamada,...
# 138398  Ünlü şarkıcı   ile oyuncu  ’un gizlice evlendi...
# 138399  Kamboçya hükümetinin müdahalesiyle ülkedeki FE...
# 138400  Kar yağışı  'un Kuzey ve Doğusunda etkili olac...
# 138401  Alınan bilgiye göre, Bilecik’in Gölpazarı ilçe...
#
#                        date          source  \
# 0       2006-01-10 11:34:00       haberturk
# 1       2018-12-25 19:00:00             DHA
# 2       2006-02-10 22:55:00       haberturk
# 3       2018-12-25 19:29:00      cumhuriyet
# 4       2006-03-10 13:50:00       haberturk
# ...                     ...             ...
# 138397  2018-12-25 17:20:00  Anadolu Ajansı
# 138398  2018-12-25 17:23:00             NaN
# 138399  2018-12-25 17:28:00  Anadolu Ajansı
# 138400  2018-12-25 17:28:00       haberturk
# 138401  2018-12-25 18:17:00      cumhuriyet
#
#                                                      tags  \
# 0                                                      []
# 1                       ['TBMM', 'Türkiye', 'Afganistan']
# 2                                                      []
# 3                                                     NaN
# 4                                                      []
# ...                                                   ...
# 138397              ['Türkiye', 'Eğitim', 'kar', 'Sivas']
# 138398                   ['Yaşam', 'magazin', 'ünlüler ']
# 138399                         ['Dünya', 'FETÖ', 'haber']
# 138400  ['istanbul', 'istanbul haberler', 'haberler', ...
# 138401                                                NaN
#
#                                                    title          topic  \
# 0                               AKP 'Babanı sustur' dedi         Gündem
# 1          'Afganistan tezkeresi' Meclis'te kabul edildi        Türkiye
# 2                      Dita soyundu kadınlar çığlık attı        Magazin
# 3                       Serbest piyasada altın fiyatları        ekonomi
# 4                      Sabancı ailesinin en gizemli ismi  Makro Ekonomi
# ...                                                  ...            ...
# 138397                       Sivas'ta eğitime kar engeli        Türkiye
# 138398        Miley Cyrus ile Liam Hemsworth evlendi mi?          Yaşam
# 138399             Kamboçya'daki FETÖ okulları kapatıldı          Dünya
# 138400          AKOM alarma geçti! İstanbul kar bekliyor         Gündem
# 138401  40 ayrı suçtan aranan cezaevi firarisi yakalandı        turkiye
#
#                                                       url
# 0       https://www.haberturk.com/gundem/haber/1717-ak...
# 1       https://www.ntv.com.tr/turkiye/afganistan-tezk...
# 2       https://www.haberturk.com/haber/haber/1795-dit...
# 3       http://www.cumhuriyet.com.tr/haber/ekonomi/118...
# 4       https://www.haberturk.com/ekonomi/makro-ekonom...
# ...                                                   ...
# 138397  https://www.ntv.com.tr/turkiye/sivasta-egitime...
# 138398  https://www.ntv.com.tr/yasam/miley-cyrus-ile-l...
# 138399  https://www.ntv.com.tr/dunya/kambocyadaki-feto...
# 138400  https://www.haberturk.com/akom-alarma-gecti-22...
# 138401  http://www.cumhuriyet.com.tr/haber/turkiye/118...
#
# [138402 rows x 11 columns]

# %%
print(*df['topic'].unique(), sep='\n')
# Out:
# Gündem
# Türkiye
# Magazin
# ekonomi
# Makro Ekonomi
# Dünya
# Medya
# Yaşam
# turkiye
# Sigorta
# nan
# Sosyal Güvenlik
# Sanat
# Kültür-Sanat
# Sağlık
# Futbol
# futbol
# Seyahat
# Polemik
# Teknoloji
# İş-Yaşam
# Eğitim
# egitim
# siyaset
# Ekonomi
# Spor
# Basketbol
# basketbol
# diger
# Enerji
# dunya
# Savunma Sanayi
# Tenis
# Diğer
# yasam
# İddaa
# Hentbol
# Olimpiyat
# BBC
# Otomobil
# Televizyon
# yerel_yonetimler
# diger_sporlar
# kultur-sanat
# Para
# 2019 Yerel Seçim
# Emlak
# spor
# Merak Edilenler
# cumhuriyet_ege
# cevre
# Nasıl Yapılır
# saglik
# Nedir
# bilim_ve_teknoloji
# Turizm
# Kadına Şiddet
# Müzik
# Motor Sporları
# Fiskos
# otomobil
# Voleybol
# Döviz
# Borsa
# Yemek Yapma
# MOTY 2019
# yazi_dizileri
# kitap
# Altın
# Alışveriş
# Ramazan
# konser
# calisma_yasami
# cumhuriyet_pazar
# Şipşak
# Dünyadan
# H. Bunu Konuşuyor
# Moda
# AIRPORT
# Özel Röportajlar
# Cemiyet Hayatı
# General
# Biyografi
# Röportajlar
# sinema
# 2016 Avrupa Şampiyonası
# surdurulebilir_yasam
# Ortak Gelecek
# Haberin Var Mı?
# Yazı Dizisi
# Seçim 2015
# Takılın
# uzay
# sokak
# foto_spor
# moda
# secim_2015
# EURO 2016
# Tarifler
# 2016 Rio Olimpiyatları
# english
# Ege Ekonomik Forum 2017
# gezi
# Bitcoin
# Seçim
# 2018 Dünya Kupası
# Akdeniz Ekonomi Forumu
# Girişimcilik
# 2018 DK Tarihçe
# Dünya Kupası 2018
# secim
# Astroloji
# pazar_yazilari
# Sıfır Atık

# %%
def frequency_dict(dataframe):
    
    topic_list = list(dataframe['topic'])
    dict_freq = dict(collections.Counter(topic_list))
    print(*dict_freq.items(), sep='\n')

# %%
df_renamed = df

df_renamed.loc[df_renamed.topic == "Futbol", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "futbol", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Basketbol", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Tenis", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Hentbol", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Olimpiyat", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "spor", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Motor Sporları", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Voleybol", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "2016 Avrupa Şampiyonası", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "foto_spor", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "EURO 2016", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "2016 Rio Olimpiyatları", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "2018 Dünya Kupası", "topic"] = "Spor"
df_renamed.loc[df_renamed.topic == "Dünya Kupası 2018", "topic"] = "Spor"

df_renamed.loc[df_renamed.topic == "turkiye", "topic"] = "Türkiye"

df_renamed.loc[df_renamed.topic == "Fiskos", "topic"] = "Magazin"

df_renamed.loc[df_renamed.topic == "ekonomi", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Makro Ekonomi", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Para", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Döviz", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Borsa", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Altın", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Ege Ekonomik Forum 2017", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Bitcoin", "topic"] = "Ekonomi"
df_renamed.loc[df_renamed.topic == "Akdeniz Ekonomi Forumu", "topic"] = "Ekonomi"

df_renamed.loc[df_renamed.topic == "dunya", "topic"] = "Dünya"
df_renamed.loc[df_renamed.topic == "Dünyadan", "topic"] = "Dünya"

df_renamed.loc[df_renamed.topic == "yasam", "topic"] = "Yaşam"

df_renamed.loc[df_renamed.topic == "Sanat", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "Kültür-Sanat", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "kultur-sanat", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "sinema", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "kitap", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "Müzik", "topic"] = "Kültür_Sanat"
df_renamed.loc[df_renamed.topic == "konser", "topic"] = "Kültür_Sanat"

df_renamed.loc[df_renamed.topic == "saglik", "topic"] = "Saglık"

df_renamed.loc[df_renamed.topic == "bilim_ve_teknoloji", "topic"] = "Teknoloji"

df_renamed.loc[df_renamed.topic == "egitim", "topic"] = "Eğitim"

df_renamed.loc[df_renamed.topic == "siyaset", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "yerel_yonetimler", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "2019 Yerel Seçim", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "Seçim 2015", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "secim_2015", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "Seçim", "topic"] = "Siyaset"
df_renamed.loc[df_renamed.topic == "secim", "topic"] = "Siyaset"

df_renamed.loc[df_renamed.topic == "Kadına Şiddet", "topic"] = "Kadına_Şiddet"

df_renamed.loc[df_renamed.topic == "otomobil", "topic"] = "Otomobil"

df_renamed.loc[df_renamed.topic == "gezi", "topic"] = "Seyahat"

df_renamed.loc[df_renamed.topic == "calisma_yasami", "topic"] = "İş"
df_renamed.loc[df_renamed.topic == "İş-Yaşam", "topic"] = "İş"

df_renamed.loc[df_renamed.topic == "cevre", "topic"] = "Çevre"
df_renamed.loc[df_renamed.topic == "Sıfır Atık", "topic"] = "Çevre"

df_renamed.loc[df_renamed.topic == "Yemek Yapma", "topic"] = "Mutfak"
df_renamed.loc[df_renamed.topic == "Tarifler", "topic"] = "Mutfak"

df_renamed.loc[df_renamed.topic == "Özel Röportajlar", "topic"] = "Röportaj"
df_renamed.loc[df_renamed.topic == "Röportajlar", "topic"] = "Röportaj"

df_renamed = df_renamed.loc[df_renamed['topic'].isin(['Spor', 'Türkiye', 'Magazin', 'Ekonomi', 
                                         'Dünya', 'Medya', 'Yaşam', 'Kültür_Sanat', 
                                         'Sağlık', 'Teknoloji', 'Eğitim', 'Siyaset', 
                                         'Enerji', 'Yemek', 'Kadına_Şiddet', 'Otomobil', 
                                         'Televizyon', 'Seyahat', 'Polemik', 'Turizm', 
                                         'İş', 'Emlak', 'Çevre'])]

# %%
frequency_dict(df_renamed)
# Out:
# ('Türkiye', 53661)
# ('Magazin', 905)
# ('Ekonomi', 10046)
# ('Dünya', 19657)
# ('Medya', 161)
# ('Yaşam', 7428)
# ('Kültür_Sanat', 4271)
# ('Sağlık', 8488)
# ('Spor', 15261)
# ('Seyahat', 251)
# ('Polemik', 155)
# ('Teknoloji', 3287)
# ('İş', 1075)
# ('Eğitim', 2674)
# ('Siyaset', 2335)
# ('Enerji', 105)
# ('Otomobil', 805)
# ('Televizyon', 148)
# ('Emlak', 138)
# ('Çevre', 84)
# ('Turizm', 110)
# ('Kadına_Şiddet', 92)

# %% [markdown]
# ### 1000

# %%
df_1000 = df_renamed.loc[df_renamed['topic'].isin(['Magazin', 'Ekonomi', 'Dünya', 'Kültür_Sanat', 
                                                   'Sağlık', 'Spor', 'Teknoloji', 
                                                   'Eğitim', 'Siyaset', 'Otomobil'])]
                         
df_1000 = df_1000.sample(1000, random_state=42)
df_1000
# Out:
#         Unnamed: 0.1  Unnamed: 0  \
# 132498        250441      159365
# 129295        244042      148721
# 135887        257147      162007
# 27873          42028      164150
# 65749         116827      240149
# ...              ...         ...
# 54093          93546      194817
# 91984         169229       14648
# 77169         139645      236574
# 133670        252771      161069
# 24103          34479      269455
#
#                                                  abstract             author  \
# 132498  Medipol Başakşehir Teknik Direktörü Abdullah A...                NaN
# 129295  Ankara'da konuşan AKP'li Cumhurbaşkanı Tayyip ...  cumhuriyet.com.tr
# 135887  Cep telefonu bağımlılığı olarak adlandırılan '...                NaN
# 27873   Başbakanlığın herhangi bir şekilde burs verme ...                NaN
# 65749   Fenerbahçeli futbolcu Ozan Tufan, daha iyi yer...  cumhuriyet.com.tr
# ...                                                   ...                ...
# 54093   Recep İvedik, gösterimdeki ilk üç gününde 1 mi...  cumhuriyet.com.tr
# 91984   Süper Lig'in 28. hafta kapanış maçında Bursasp...  cumhuriyet.com.tr
# 77169   Merkez Bankası Başkanı Başçı, 2016'nın enflasy...                NaN
# 133670  Afganistan'ın başkenti Kabil'de meydana gelen ...                NaN
# 24103   BM Kadına Karşı Her Türlü Ayrımcılığın Ortadan...                NaN
#
#                                                   content  \
# 132498  Türkiye Futbol Antrenörleri Derneği'nin (TÜFAD...
# 129295  Erdoğan'ın yaptığı konuşmadan öne çıkan kısıml...
# 135887  nin telefondan uzak kalamama hastalığı olduğun...
# 27873   Başbakanlık Basın Merkezi internet sitesinde y...
# 65749   Fenerbahçeli futbolcu Ozan Tufan, daha iyi yer...
# ...                                                   ...
# 54093   Geçen hafta vizyona giren Recep İvedik 4, üç g...
# 91984   Beşiktaş, Spor Toto Süper Lig'de 28. hafta kar...
# 77169   Merkez Bankası Başkanı Erdem Başçı'dan yeni aç...
# 133670  Afganistan'ın başkenti Kabil'in Kara Bağ İlçe ...
# 24103   BM Kadına Karşı Her Türlü Ayrımcılığın Ortadan...
#
#                        date          source  \
# 132498  2018-10-01 16:37:00         Ntvspor
# 129295  2018-08-14 11:37:00      cumhuriyet
# 135887  2018-11-20 14:31:00             DHA
# 27873   2010-12-20 17:59:00  Anadolu Ajansı
# 65749   2015-05-10 16:54:00      cumhuriyet
# ...                     ...             ...
# 54093   2014-02-24 20:17:00      cumhuriyet
# 91984   2016-11-04 09:47:00      cumhuriyet
# 77169   2016-01-25 12:09:00  Anadolu Ajansı
# 133670  2018-10-19 15:33:00  Anadolu Ajansı
# 24103   2010-08-18 14:09:00  Anadolu Ajansı
#
#                                                      tags  \
# 132498  ['Spor', 'Futbol', 'Başakşehir Futbol Kulübü',...
# 129295                                                NaN
# 135887  ['Psikoloji', 'Cep telefonu', 'İstanbul', 'nom...
# 27873                                                  []
# 65749                                                 NaN
# ...                                                   ...
# 54093                                                 NaN
# 91984                                                 NaN
# 77169                                         ['Ekonomi']
# 133670   ['Dünya', 'Trafik Kazası', 'Asya', 'Afganistan']
# 24103                                                  []
#
#                                                     title         topic  \
# 132498     Abdullah Avcı: Arda transferi kolay gözükmüyor          Spor
# 129295  Erdoğan: Amerika’nın elektronik ürünlerine biz...       Siyaset
# 135887  “Cep telefonu bağımlılığı nomofobi yüzünden mu...        Sağlık
# 27873            Başbakanlık’tan 500 lira burs açıklaması        Eğitim
# 65749               Ozan'ın büyük iddiası: "Rahat oluruz"          Spor
# ...                                                   ...           ...
# 54093                 Recep İvedik 4 kendi rekorunu kırdı  Kültür_Sanat
# 91984            Ve Beşiktaş taraftarı stadına kavuşuyor!          Spor
# 77169         Erdem Başçı: Enflasyon problemini çözeceğiz       Ekonomi
# 133670                Afganistan'da trafik kazası: 20 ölü         Dünya
# 24103        CEDAW: Türban yasağının etkilerini araştırın         Dünya
#
#                                                       url
# 132498  https://www.ntv.com.tr/spor/abdullah-avci-arda...
# 129295  http://www.cumhuriyet.com.tr/haber/siyaset/105...
# 135887  https://www.ntv.com.tr/saglik/cep-telefonu-bag...
# 27873   https://www.ntv.com.tr/egitim/basbakanliktan-5...
# 65749   http://www.cumhuriyet.com.tr/haber/futbol/3819...
# ...                                                   ...
# 54093   http://www.cumhuriyet.com.tr/haber/sinema/4465...
# 91984   http://www.cumhuriyet.com.tr/haber/futbol/5134...
# 77169   https://www.ntv.com.tr/ekonomi/erdem-basci-enf...
# 133670  https://www.ntv.com.tr/dunya/afganistanda-traf...
# 24103   https://www.ntv.com.tr/dunya/cedaw-turban-yasa...
#
# [1000 rows x 11 columns]

# %%
frequency_dict(df_1000)
# Out:
# ('Spor', 225)
# ('Siyaset', 31)
# ('Sağlık', 128)
# ('Eğitim', 43)
# ('Ekonomi', 132)
# ('Dünya', 304)
# ('Otomobil', 15)
# ('Teknoloji', 52)
# ('Kültür_Sanat', 63)
# ('Magazin', 7)

# %%
df_1000 = df_1000[['abstract', 'title', 'topic']]
df_1000.to_csv("df_1000.csv", sep='\t', encoding="utf-8")
# Out:
#                                                  abstract  \
# 132498  Medipol Başakşehir Teknik Direktörü Abdullah A...
# 129295  Ankara'da konuşan AKP'li Cumhurbaşkanı Tayyip ...
# 135887  Cep telefonu bağımlılığı olarak adlandırılan '...
# 27873   Başbakanlığın herhangi bir şekilde burs verme ...
# 65749   Fenerbahçeli futbolcu Ozan Tufan, daha iyi yer...
# ...                                                   ...
# 54093   Recep İvedik, gösterimdeki ilk üç gününde 1 mi...
# 91984   Süper Lig'in 28. hafta kapanış maçında Bursasp...
# 77169   Merkez Bankası Başkanı Başçı, 2016'nın enflasy...
# 133670  Afganistan'ın başkenti Kabil'de meydana gelen ...
# 24103   BM Kadına Karşı Her Türlü Ayrımcılığın Ortadan...
#
#                                                     title         topic
# 132498     Abdullah Avcı: Arda transferi kolay gözükmüyor          Spor
# 129295  Erdoğan: Amerika’nın elektronik ürünlerine biz...       Siyaset
# 135887  “Cep telefonu bağımlılığı nomofobi yüzünden mu...        Sağlık
# 27873            Başbakanlık’tan 500 lira burs açıklaması        Eğitim
# 65749               Ozan'ın büyük iddiası: "Rahat oluruz"          Spor
# ...                                                   ...           ...
# 54093                 Recep İvedik 4 kendi rekorunu kırdı  Kültür_Sanat
# 91984            Ve Beşiktaş taraftarı stadına kavuşuyor!          Spor
# 77169         Erdem Başçı: Enflasyon problemini çözeceğiz       Ekonomi
# 133670                Afganistan'da trafik kazası: 20 ölü         Dünya
# 24103        CEDAW: Türban yasağının etkilerini araştırın         Dünya
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### helsinki-backtranslation

# %%
df_helsinki = pd.read_csv("df_helsinki.csv", sep=",", encoding="utf-8")
df_helsinki
# Out:
#                                               abstract         topic  \
# 0    medipol başakşehir teknik direktörü abdullah a...          Spor
# 1    ankara'da konuşan akp'li cumhurbaşkanı tayyip ...       Siyaset
# 2    cep telefonu bağımlılığı olarak adlandırılan '...        Sağlık
# 3    başbakanlığın herhangi bir şekilde burs verme ...        Eğitim
# 4    fenerbahçeli futbolcu ozan tufan, daha iyi yer...          Spor
# ..                                                 ...           ...
# 995  recep i̇vedik, gösterimdeki ilk üç gününde 1 m...  Kültür_Sanat
# 996  süper lig'in 28. hafta kapanış maçında bursasp...          Spor
# 997  merkez bankası başkanı başçı, 2016'nın enflasy...       Ekonomi
# 998  afganistan'ın başkenti kabil'de meydana gelen ...         Dünya
# 999  bm kadına karşı her türlü ayrımcılığın ortadan...         Dünya
#
#                                              backtrans
# 0    "Onunla ilgili bir sorun olacağını sanmıyorum ...
# 1    Ankara'da konuşan Akp cumhurbaşkanı, abd'ye 's...
# 2    "Hayatımız artık çok mutlu değil. Doğayla pek ...
# 3    Başbakan'ın herhangi bir şekilde burs verme ba...
# 4    Daha iyi yerlere geleceğini düşünerek sarı-lac...
# ..                                                 ...
# 995  Programımın ilk üç gününde Recep, hafta sonu i...
# 996  Vodafone arenasında Süper Lig'in 28. hafta kap...
# 997  Merkez bankası başkanı, "Enflasyonla mücadele ...
# 998  Afganistan'ın başkenti Kabil'de meydana gelen ...
# 999  Kadınlara yönelik tüm ayrımcılığın kaldırılmas...
#
# [1000 rows x 3 columns]

# %%
df_helsinki = pd.read_csv("df_helsinki.csv", sep=",", encoding="utf-8")
df_helsinki['title'] = df_1000['title']
df_helsinki = df_helsinki.drop('abstract', axis=1)
df_helsinki = df_helsinki.rename(columns = {'backtrans':'abstract'})
df_helsinki = df_helsinki[['abstract', 'title', 'topic']]
df_helsinki
# Out:
#                                               abstract  \
# 0    "Onunla ilgili bir sorun olacağını sanmıyorum ...
# 1    Ankara'da konuşan Akp cumhurbaşkanı, abd'ye 's...
# 2    "Hayatımız artık çok mutlu değil. Doğayla pek ...
# 3    Başbakan'ın herhangi bir şekilde burs verme ba...
# 4    Daha iyi yerlere geleceğini düşünerek sarı-lac...
# ..                                                 ...
# 995  Programımın ilk üç gününde Recep, hafta sonu i...
# 996  Vodafone arenasında Süper Lig'in 28. hafta kap...
# 997  Merkez bankası başkanı, "Enflasyonla mücadele ...
# 998  Afganistan'ın başkenti Kabil'de meydana gelen ...
# 999  Kadınlara yönelik tüm ayrımcılığın kaldırılmas...
#
#                                                  title         topic
# 0       Abdullah Avcı: Arda transferi kolay gözükmüyor          Spor
# 1    Erdoğan: Amerika’nın elektronik ürünlerine biz...       Siyaset
# 2    “Cep telefonu bağımlılığı nomofobi yüzünden mu...        Sağlık
# 3             Başbakanlık’tan 500 lira burs açıklaması        Eğitim
# 4                Ozan'ın büyük iddiası: "Rahat oluruz"          Spor
# ..                                                 ...           ...
# 995                Recep İvedik 4 kendi rekorunu kırdı  Kültür_Sanat
# 996           Ve Beşiktaş taraftarı stadına kavuşuyor!          Spor
# 997        Erdem Başçı: Enflasyon problemini çözeceğiz       Ekonomi
# 998                Afganistan'da trafik kazası: 20 ölü         Dünya
# 999       CEDAW: Türban yasağının etkilerini araştırın         Dünya
#
# [1000 rows x 3 columns]

# %%
frequency_dict(df_helsinki)
# Out:
# ('Spor', 225)
# ('Siyaset', 31)
# ('Sağlık', 128)
# ('Eğitim', 43)
# ('Ekonomi', 132)
# ('Dünya', 304)
# ('Otomobil', 15)
# ('Teknoloji', 52)
# ('Kültür_Sanat', 63)
# ('Magazin', 7)

# %%
df_helsinki.to_csv("df_helsinki.csv", sep='\t')

# %%
df_hel = pd.read_csv("df_helsinki.csv")
df_hel = df_hel.drop('title', axis=1)
df_hel = df_hel.rename(columns = {'backtrans':'title'})
df_hel = df_hel[['title', 'topic']]
# Out:
#                                                  title         topic
# 0             Abdullah Avcı: Transfer kolay görünmüyor          Spor
# 1    Erdoğan: Amerikan elektronik ürünlerini boykot...       Siyaset
# 2    Cep telefonu bağımlılığından dolayı nomofobide...        Sağlık
# 3          Başbakanlık'tan 500 liralık burs açıklaması        Eğitim
# 4               Ozan'ın büyük iddiası, "İyi olacağız."          Spor
# ..                                                 ...           ...
# 995                Recep İvedik 4 kendi rekorunu kırdı  Kültür_Sanat
# 996                       Ve beşik fan stadını alıyor!          Spor
# 997            Erdem Şef: Enflasyon sorununu çözeceğiz       Ekonomi
# 998               Afganistan'da trafik kazası: 20 ölü.         Dünya
# 999    Cedaw: Başörtüsü yasağının etkilerini inceleyin         Dünya
#
# [1000 rows x 2 columns]

# %%
df_hel[df_hel['title'].isnull()].index.tolist()
# Out:
# [264, 314, 341, 359]

# %%
len(df_hel.drop(index=[264, 314, 341, 359]))
# Out:
# 996

# %%
df_1000_hel = pd.concat([df_1000, df_hel])
# Out:
#                                                  title         topic
# 0       Abdullah Avcı: Arda transferi kolay gözükmüyor          Spor
# 1    Erdoğan: Amerika’nın elektronik ürünlerine biz...       Siyaset
# 2    “Cep telefonu bağımlılığı nomofobi yüzünden mu...        Sağlık
# 3             Başbakanlık’tan 500 lira burs açıklaması        Eğitim
# 4                Ozan'ın büyük iddiası: "Rahat oluruz"          Spor
# ..                                                 ...           ...
# 995                Recep İvedik 4 kendi rekorunu kırdı  Kültür_Sanat
# 996                       Ve beşik fan stadını alıyor!          Spor
# 997            Erdem Şef: Enflasyon sorununu çözeceğiz       Ekonomi
# 998               Afganistan'da trafik kazası: 20 ölü.         Dünya
# 999    Cedaw: Başörtüsü yasağının etkilerini inceleyin         Dünya
#
# [2000 rows x 2 columns]

# %%
df_1000_hel.iloc[6]['title']
# Out:
# 'Temer, Rio 2016 kapanış törenine katılmayacak'

# %%
df_1000_hel.iloc[1006]['title']
# Out:
# "Temer, 2016 Rio'nun kapanış törenine katılmayacak"

# %% [markdown]
# ## Detailing

# %%
df_det = pd.read_csv("df_detailed.csv", sep='\t')
df_det = df_det.drop('title', axis=1)
df_det = df_det.rename(columns = {'detailed':'title'})
df_det = df_det[['title', 'topic']]
df_det
# Out:
#                                                  title         topic
# 0    ['Sona eren antrenman günkü maçında Fenerbahçe...          Spor
# 1    ["Cumhurbaşkanı Recep Tayyip Erdoğan, ''Amerik...       Siyaset
# 2    ['ABD’de yaşayan oyuncu, cep telefonu bağımlıl...        Sağlık
# 3    ['Başbakanlık, İzmir Emniyet Müdürlüğü arazile...        Eğitim
# 4    ['Fenerbahçe, Galatasaray’ı 3-0 yenerek, Trabz...          Spor
# ..                                                 ...           ...
# 995        ["İlk maçlar başında 'Ülkemiz' gibi oldu."]  Kültür_Sanat
# 996  ["Süper Lig'de sezonun 7. haftasında Beşiktaş ...          Spor
# 997  ['Ekonomi Bakanı Erdem Başçı, bankaların net v...       Ekonomi
# 998  ["Afganistan'ın başkenti Manila'da meydana gel...         Dünya
# 999  ['ABD Başkanı Donald Trump, Trump\'ın Avrupa K...         Dünya
#
# [1000 rows x 2 columns]

# %%
df_1000_det = pd.concat([df_1000, df_det])
df_1000_det
# Out:
#                                                  title         topic
# 0       Abdullah Avcı: Arda transferi kolay gözükmüyor          Spor
# 1    Erdoğan: Amerika’nın elektronik ürünlerine biz...       Siyaset
# 2    “Cep telefonu bağımlılığı nomofobi yüzünden mu...        Sağlık
# 3             Başbakanlık’tan 500 lira burs açıklaması        Eğitim
# 4                Ozan'ın büyük iddiası: "Rahat oluruz"          Spor
# ..                                                 ...           ...
# 995        ["İlk maçlar başında 'Ülkemiz' gibi oldu."]  Kültür_Sanat
# 996  ["Süper Lig'de sezonun 7. haftasında Beşiktaş ...          Spor
# 997  ['Ekonomi Bakanı Erdem Başçı, bankaların net v...       Ekonomi
# 998  ["Afganistan'ın başkenti Manila'da meydana gel...         Dünya
# 999  ['ABD Başkanı Donald Trump, Trump\'ın Avrupa K...         Dünya
#
# [2000 rows x 2 columns]

# %%
df_1000_det.iloc[6]['title']
# Out:
# 'Temer, Rio 2016 kapanış törenine katılmayacak'

# %%
df_1000_det.iloc[1006]['title']
# Out:
# "['Temer, Rio 2016’ya katılma girişiminin ardından ilk kez gerçekleştirilecek olan törene katılmayacak.']"

# %%
df_1000_hel.to_csv('df_1000_helsinki.csv', sep='\t')
df_1000_det.to_csv('df_1000_detailed.csv', sep='\t')
